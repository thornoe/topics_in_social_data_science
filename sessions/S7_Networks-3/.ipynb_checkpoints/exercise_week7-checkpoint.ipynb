# %% [markdown]
# > **Note:** In most sessions you will be solving exercises posed in a Jupyter notebook that looks like this one. Because you are cloning a Github repository that only we can push to, you should **NEVER EDIT** any of the files you pull from Github. Instead, what you should do, is either make a new notebook and write your solutions in there, or **make a copy of this notebook and save it somewhere else** on your computer, not inside the `sds` folder that you cloned, so you can write your answers in there. If you edit the notebook you pulled from Github, those edits (possible your solutions to the exercises) may be overwritten and lost the next time you pull from Github. This is important, so don't hesitate to ask if it is unclear.

# %%
# Use SHIFT+TAB to view documentation

# %matplotlib inline
import pandas as pd
import matplotlib.pylab as plt
import statsmodels as sm # !pip install statsmodels
import statsmodels.formula.api as smf
# Out:
# Requirement already satisfied: statsmodels in c:\users\thorn\anaconda3\lib\site-packages (0.9.0)

# %%
# pyplot options
def opt(color):
    options = {
        's': 30,
        'color':color,
        'marker':'o',
        'alpha': 0.1
    }
    return options

# figure size and axis dimensions
plt.rcParams["figure.figsize"] = (10,6)

xmin = -6
xmax =  6
ymin = -6
ymax =  6
v = [xmin, xmax, ymin, ymax]

def scatter(x, y, color='b'):
    plt.scatter(x, y, **opt(color))
    plt.axis(v)

# %% [markdown]
# # Exercise Set 7: Peer effects
#
# *February 20, 2019*
#
# In this Exercise Set 7 we will investigate peer effects data.

# %% [markdown]
# ## 7.1: roommate peer effects
#
#
# <br>
# <br>
#
# Due to a lack of available peer effects data we will use a simlated dataset which will give results that provide conclusions similar to Sacerdote (2000).
#
# ### Data structuring
#
# Our data set does not contain a network but has an implicit one associated. We assume there is an edge between all room mates.
#
# > **Ex. 7.1.1:** Create a column called `person_other` with identity of the other person in room.
# >> *Hint:* You can get the unique people in the room by using `df.groupby('room').person.unique()`.

# %%
# [Answer to ex. 7.1.1 here]
def f(person_id, list_of_ids):
    for i in list_of_ids:
        if i == person_id:
            continue
        return i

print('This is a test:', f(1, [1,2]))

df = pd.read_csv('peer_effects_room.csv')
df2 = pd.DataFrame( df.groupby('room').person.unique() )
df2.columns = ['person_y']
df = df.merge(df2, on='room').sort_values('person').reset_index(drop=True)

df['other'] = df.apply(lambda x: f(x['person'], x['person_y']), axis=1)
df.drop('person_y', axis=1, inplace=True)
df.head()
# Out:
# This is a test: 2
#    person  room  high_school_GPA  college_GPA  other
# 0       0   351        -1.715472    -1.285307   1645
# 1       1   738        -0.530190    -0.031833   1039
# 2       2   247        -0.589543    -0.203230    944
# 3       3   751        -1.303115     0.982488   1099
# 4       4   698         0.156678    -0.371632   1708

# %% [markdown]
# <br>
#
# > **Ex. 7.1.2:** Add information on the roommate GPA in high school and college.
# >> *Hint:* This can be done merging on `person_other`.

# %%
# [Answer to ex. 7.1.2 here]
dat = df.merge(df, left_on='other', right_on='person')
dat = dat[['person_x','room_x','high_school_GPA_x','college_GPA_x','person_y','high_school_GPA_y','college_GPA_y']]
dat.rename(columns={'room_x':'room'}, inplace=True)
dat.head()
# Out:
#    person_x  room  high_school_GPA_x  college_GPA_x  person_y  \
# 0         0   351          -1.715472      -1.285307      1645
# 1         1   738          -0.530190      -0.031833      1039
# 2         2   247          -0.589543      -0.203230       944
# 3         3   751          -1.303115       0.982488      1099
# 4         4   698           0.156678      -0.371632      1708
#
#    high_school_GPA_y  college_GPA_y
# 0          -0.818594      -0.434847
# 1          -0.493444       0.299729
# 2           1.281112      -0.479543
# 3          -1.812137      -2.267394
# 4          -0.327219       0.670683

# %% [markdown]
# <br>
# <br>
#
# ### Data exploration and randomization
#
# We now have our final dataset and can begin investigating how the raw data looks.
#
# > **Ex. 7.1.3:** plot own GPA in high school vs college in a scatter plot.

# %%
# [Answer to ex. 7.1.3 here]
scatter(dat['high_school_GPA_x'], dat['college_GPA_x'], 'b')

# %% [markdown]
# <br>
# We want to check there is random assignment of roommates.
#
# > **Ex. 7.1.4:** Plot high school GPA vs roommate's high school GPA. Comment on the output. Run a regresion of high school GPA on roommate's high school GPA to formally check random assignment.
# >
# >> *Hint*: To run regressions in python, you can use the `statsmodels` package. Look up it's documentation and use the `.formula` api to estimate your model. To see a summary of a fitted model you can call `.summary()` on the object.
# >
# >> *Hint:* Under random assignment we would expect there to be no relation between the high school GPA's of roommates. Why is this?

# %%
# [Answer to ex. 7.1.4 here]
scatter(dat['high_school_GPA_y'], data['high_school_GPA_x'], 'r')
check = smf.ols('high_school_GPA_x ~ high_school_GPA_y', data=dat).fit()
check.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:      high_school_GPA_x   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                   0.07263
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):              0.788
# Time:                        17:23:30   Log-Likelihood:                -2883.6
# No. Observations:                2000   AIC:                             5771.
# Df Residuals:                    1998   BIC:                             5782.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -0.0284      0.023     -1.241      0.215      -0.073       0.016
# high_school_GPA_y    -0.0060      0.022     -0.269      0.788      -0.050       0.038
# ==============================================================================
# Omnibus:                        0.231   Durbin-Watson:                   1.911
# Prob(Omnibus):                  0.891   Jarque-Bera (JB):                0.288
# Skew:                           0.015   Prob(JB):                        0.866
# Kurtosis:                       2.949   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# <br>
# <br>
#
# ## Roommate effect
#
# Having checked the data we move on to analyzing peer effects. We begin with analyzing **exogenous** peer effects. I.e. peer effects that are related to the ex ante characteristics of the roommate.
#
# > **Ex. 7.1.5:** Plot own GPA in college vs. roommate GPA in high school. Comment on the output. Test whether there is an impact using a regresion of college school GPA on high school GPA for the person itself and its roommate.

# %%
# [Answer to ex. 7.1.5 here]
scatter(dat['high_school_GPA_y'], dat['college_GPA_x'], 'g')
plt.axis()
res1 = smf.ols('college_GPA_x ~ high_school_GPA_y', data=dat).fit()
res1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          college_GPA_x   R-squared:                       0.001
# Model:                            OLS   Adj. R-squared:                  0.000
# Method:                 Least Squares   F-statistic:                     1.584
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):              0.208
# Time:                        17:23:56   Log-Likelihood:                -3099.5
# No. Observations:                2000   AIC:                             6203.
# Df Residuals:                    1998   BIC:                             6214.
# Df Model:                           1
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -0.0427      0.026     -1.674      0.094      -0.093       0.007
# high_school_GPA_y     0.0314      0.025      1.259      0.208      -0.018       0.080
# ==============================================================================
# Omnibus:                      120.285   Durbin-Watson:                   1.904
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              484.476
# Skew:                          -0.100   Prob(JB):                    6.27e-106
# Kurtosis:                       5.403   Cond. No.                         1.04
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# We now move on to analyze **endogenous** peer effects.
#
# > **Ex. 7.1.6:** Test whether there is an association between own college GPA and roommates. Do this by running a regresion of college school GPA on high school GPA for the person itself and its roommate. Comment on the output.

# %%
# [Answer to ex. 7.1.6 here]
res2 = smf.ols('college_GPA_x ~ high_school_GPA_x + high_school_GPA_y', data=dat).fit()
res2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          college_GPA_x   R-squared:                       0.402
# Model:                            OLS   Adj. R-squared:                  0.401
# Method:                 Least Squares   F-statistic:                     671.3
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):          1.03e-223
# Time:                        17:06:06   Log-Likelihood:                -2586.0
# No. Observations:                2000   AIC:                             5178.
# Df Residuals:                    1997   BIC:                             5195.
# Df Model:                           2
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -0.0226      0.020     -1.147      0.252      -0.061       0.016
# high_school_GPA_x     0.7059      0.019     36.606      0.000       0.668       0.744
# high_school_GPA_y     0.0356      0.019      1.847      0.065      -0.002       0.073
# ==============================================================================
# Omnibus:                       77.587   Durbin-Watson:                   1.951
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              213.025
# Skew:                          -0.117   Prob(JB):                     5.52e-47
# Kurtosis:                       4.582   Cond. No.                         1.05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
# With endogeneity problem (dynamic / two-way effect)
scatter(dat['college_GPA_y'], dat['college_GPA_x'], 'y')
res3 = smf.ols('college_GPA_x ~ high_school_GPA_x + high_school_GPA_y + college_GPA_y', data=dat).fit()
res3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          college_GPA_x   R-squared:                       0.405
# Model:                            OLS   Adj. R-squared:                  0.405
# Method:                 Least Squares   F-statistic:                     453.7
# Date:                Wed, 20 Mar 2019   Prob (F-statistic):          1.02e-224
# Time:                        17:26:23   Log-Likelihood:                -2580.3
# No. Observations:                2000   AIC:                             5169.
# Df Residuals:                    1996   BIC:                             5191.
# Df Model:                           3
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept            -0.0209      0.020     -1.063      0.288      -0.060       0.018
# high_school_GPA_x     0.7032      0.019     36.530      0.000       0.665       0.741
# high_school_GPA_y    -0.0176      0.025     -0.708      0.479      -0.066       0.031
# college_GPA_y         0.0754      0.022      3.378      0.001       0.032       0.119
# ==============================================================================
# Omnibus:                       79.457   Durbin-Watson:                   1.956
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              221.843
# Skew:                          -0.117   Prob(JB):                     6.72e-49
# Kurtosis:                       4.615   Cond. No.                         2.14
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# <br>
# <br>
#
# # 7.2 Peer effects in Danish classrooms
#
# Read the [report by Kraka on peer effects in Danish schools](http://kraka.org/sites/default/files/public/baggrundsnotat_klassekammerateffekter_0.pdf). If you do not speak Danish talk to your group about the content.
# > **Ex. 7.2.1:** Explain the identification strategy in words.

# %% [markdown]
# > **Ex. 7.2.2:** Are there any shortcomings of the identification strategy? What does the seminal paper [Hoxby (2000)](https://www.nber.org/papers/w7867.pdf) test for?

# %% [markdown]
# **Answer:** Kraka doesn't control for teacher effects.

# %% [markdown]
# > **Ex. 7.2.3:** Try to come up with identification strategies for identifying peer effects in the context of Danish class rooms.
